# %% [markdown]
# <a href="https://colab.research.google.com/github/EasyGUIs/notebok/blob/main/webui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title ## **Install**


import os
import codecs
from IPython.display import clear_output
print("Installing requirements")
repo = "https://huggingface.co/R-Kentaren/EasyGUI"

# !git clone {repo} main_program
# %cd main_program
# !pip install uv pyngrok
# !uv pip install -r requirements.txt
# !apt install sox
clear_output()
print("Requirements installed!")
# Out:
# Requirements installed!

# %%
#@title **Run webui**


runtime = "app.py"
# !git pull -q
# !python $runtime --share

# %% [markdown]
# notebook fix made by [BF667](https://github.com/BF667/AICG)
#
#
# pls star my fork and follow me
